# %%
# 09/04/20- reproducing Figs 2 and 3 in Kooi et al. 2017 using the output from plots_Ts_set_onset_time_PDFs.ipynb

import matplotlib.pyplot as plt
import pickle 
dirwrite = '/home/dlobelle/Kooi_figures/3D_NPacific_10x10grid/'

with open('/home/dlobelle/Kooi_data/data_input/Ts_Vs_rho840.pickle', 'rb') as Ts: #T_settling_rho840
    Ts_840, Vs_840 = pickle.load(Ts)

with open('/home/dlobelle/Kooi_data/data_input/Ts_Vs_rho920.pickle', 'rb') as Ts:
    Ts_920, Vs_920 = pickle.load(Ts)
    
with open('/home/dlobelle/Kooi_data/data_input/Ts_Vs_rho940.pickle', 'rb') as Ts:
    Ts_940, Vs_940 = pickle.load(Ts)
    
plt.plot(np.flip(Ts_840),'-o', label='density = 840 kg m-3')
plt.plot(np.flip(Ts_920),'-o', label='density = 920 kg m-3')
plt.plot(np.flip(Ts_940),'-o', label='density = 940 kg m-3')
plt.xticks([0, 1, 2, 3], ['10-7','10-6','10-5','10-4'])
plt.legend() #(line1,line2,line3),('density = 840 kgm-3','density = 920 kgm-3','density = 940 kgm-3'))
plt.title('Settling onset time')
plt.xlabel('radius [m]')
plt.ylabel('onset time [days]')
plt.show()

plt.savefig(dirwrite + 'Ts_sett_onset_time_all_rho_sizes(10x10grid).pdf', format='pdf')

# %%
plt.plot(np.flip(Vs_840),'-o', label='density = 840 kg m-3')
plt.plot(np.flip(Vs_920),'-o', label='density = 920 kg m-3')
plt.plot(np.flip(Vs_940),'-o', label='density = 940 kg m-3')
plt.xticks([0, 1, 2, 3], ['10-7','10-6','10-5','10-4'])
plt.yscale('log')
plt.title('Maximum settling velocity [m d-1]')
plt.xlabel('radius [m]')
plt.ylabel('settling velocity [m d-1]')
plt.legend() #(line1,line2,line3),('density = 840 kgm-3','density = 920 kgm-3','density = 940 kgm-3'))
plt.show()

plt.savefig(dirwrite + 'Vs_max_sett_velocity_all_rho_sizes(10x10grid).pdf', format='pdf')
