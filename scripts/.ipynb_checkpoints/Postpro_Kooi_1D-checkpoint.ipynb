# %%
# 23 January 2020
# Post-processing of 1D runs (using animations)

from netCDF4 import Dataset
import matplotlib.pyplot as plt
from matplotlib import animation

dirwrite = '/home/dlobelle/Kooi_project/data/Kooi_output/'

#print(t.shape)

# %%
data = Dataset(dirwrite +'run1_110d_rho920_rpl10-3_v2.nc')

t = data['time'][:]
z = data['z'][:]

t_yrs = t/86400.
idx = [t_yrs>=100]
t_100y_end = t_yrs[idx]
z_100y_end = z[idx]

plt.figure()
plt.plot(t_100y_end,z_100y_end,'-')
plt.xlabel('Time [days]')
plt.ylabel('Depth [m]') # double check units 
plt.title('radius = 1mm, density = 920kg m-3 ')
plt.ylim((0, 80)) 
plt.gca().invert_yaxis()

# %%
data1 = Dataset(dirwrite +'run1_150d_rho920_rpl10-4_v3.nc')

t1 = data1['time'][:]
z1 = data1['z'][:]

t1_yrs = t1/86400.
idx1 = [t1_yrs>=100]
t1_100y_end = t1_yrs[idx1]
z1_100y_end = z1[idx1]

plt.figure()
plt.plot(t1_100y_end,z1_100y_end,'-')
plt.xlabel('Time [days]')
plt.ylabel('Depth [m]') # double check units 
plt.title('radius = 0.1mm, density = 920kg m-3 ')
plt.ylim((0, 80)) 
plt.gca().invert_yaxis()

# %%
data2 = Dataset(dirwrite +'run1_1000d_rho920_rpl10-5.nc')
t2 = data2['time'][:]
z2 = data2['z'][:]

t2_yrs = t2/86400.
idx2 = [t2_yrs>=100]
t2_100y_end = t2_yrs[idx2]
z2_100y_end = z2[idx2]

plt.figure()
plt.plot(t2_100y_end,z2_100y_end,'-')
plt.xlabel('Time [days]')
plt.ylabel('Depth [m]') # double check units 
plt.title('radius = 10um, density = 920kg m-3 ')
plt.ylim((0, 80)) 
plt.gca().invert_yaxis()

# %%
data3 = Dataset(dirwrite +'run1_10000d_rho920_rpl10-6.nc')
t3 = data3['time'][:]
z3 = data3['z'][:]

t3_yrs = t3/86400.
idx3 = [t3_yrs>=100]
t3_100y_end = t3_yrs[idx3]
z3_100y_end = z3[idx3]

plt.figure()
plt.plot(t3_100y_end,z3_100y_end,'-')
plt.xlabel('Time [days]')
plt.ylabel('Depth [m]') # double check units 
plt.title('radius = 1um, density = 920kg m-3 ')
plt.ylim((0, 80)) 
plt.gca().invert_yaxis()

# %%
#------------ Animation attempt-----------
# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib.animation as animation

# x = np.linspace(0, 10, 100)
# y = np.sin(x)

# fig, ax = plt.subplots()
# line, = ax.plot(x, y, color='k')

# def update(num, x, y, line):
#     line.set_data(x[:num], y[:num])
#     line.axes.axis([0, 10, 0, 1])
#     return line,

# ani = animation.FuncAnimation(fig, update, len(x), fargs=[x, y, line],
#                               interval=25, blit=False)
# ani.save('test.gif')
# plt.show()

# %%
# Plotting full data
#plt.plot(t/86400.,z,'o')
#plt.gca().invert_yaxis()
